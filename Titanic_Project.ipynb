# %% [markdown]
# # Titanic Project
# Problem Statement:
#  The Titanic Problem is based on the sinking of the ‘Unsinkable’ ship Titanic in early 1912. It gives you information about multiple people like their ages, sexes, sibling counts, embarkment points, and whether or not they survived the disaster. Based on these features, you have to predict if an arbitrary passenger on Titanic would survive the sinking or not.
#
# Note: You can find the dataset in the link below.
# Downlaod Files:
# https://github.com/dsrscientist/dataset1/blob/master/titanic_train.csv

# %% [markdown]
# Dataset Description:
#
# Passenger ID : It is the unique id given to each passenger from 1-891.
#
# Survived : 0-Dead, 1-Survived.
#
# Pclass : Ticket class ,1st class-1, 2nd class-2, 3rd class-3.
#
# Name : Name of the Passenger.
#
# Sex : Sex of the passenger(male, female or third gender).
#
# SibSp : Number of siblings or spouses.
#
# Parch : Number of parents / children aboard the titanic.
#
# Ticket : Ticket number.
#
# Fare : Passenger Fare.
#
# Cabin : Cabin number.
#
# Embarked : Port of Embarkation:- C-Cherbourg, Q-Queenstown, S-Southampton

# %% [markdown]
# # Importing data:

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Titanic_Train1.csv") #reading the csv file
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# By looking into my titanic data set and reading the problem statement i can say that survived is my target column and my target column data is classifaction(integer) type, So i can conclude that my titanic project is a Classification problem.

# %% [markdown]
# # EDA:

# %%
#Checking shape of dataset
df.shape
# Out:
# (891, 12)

# %% [markdown]
# My data set contains 891 rows and 12 columns.

# %%
#reading all column names
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# I got all column names of my dataset.

# %%
#Checking data types of each feature
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# Look here i got PassengerID, Survived, Pclass, SibSp, Parch as integer type data, Name, Sex, Ticket, Cabin, Embarked as object type data and Age, Fare as float type data.

# %%
#Checking info of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# I can notice that in column Age, Cabin and column Embarked there are null values.So i have to handle them in future steps.

# %%
#Checking unique values in each column
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# Above are the list of unique count in each column.

# %%
#Checking the number of null values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# I can see 177 null values in Age column, 687 null values in Cabin column and 2 null values in Embarked column.

# %%
#Checking unique values in target column
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# In my target column i have only two unique values as 0-Dead and 1-Survived.

# %%
#Checking for any empty observation in target column
df.loc[df['Survived'] == " "]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# I can notice there is no empty observation in my target column.

# %%
#Checking for value count of target column
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# So the value counts of unique element in target is as above, they look imbalanced.I have to balance them.

# %%
#describing the data set
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# I can see the statistics of my data set and some columns are missing since they are object type data i have to encode them. Some observations:
#
# 1.There are a total of 891 passengers in our dataset.
#
# 2.There are very less mean value for the survived ,it means very less people survived.
#
# 3.The mean of age are around 30,it means maxm middle age people were travelling.
#
# 4.For age minm value is 0.42,it means some infants were also travelling (of few months).
#
# 5.We also notice that age contains some missing values.

# %% [markdown]
# # Visualization:

# %% [markdown]
# # Univariate Analysis:

# %%
#Count plot for target
sns.countplot(df['Survived']);

# %% [markdown]
# I can notice a data imbalancing in my target.I can balance either using oversampling or under sampling.Since i may loose data in undersampling so it is prefered to use oversampling.

# %%
#Factor plot for pclass
sns.factorplot('Pclass',kind='count',data=df,hue='Survived')

# %% [markdown]
# I can see the people in class 3 has less survilence and more death, in class 2 bith death and survilence are almost same, and in class 1 survilence is more than death.

# %%
#Factor plot for sex
sns.factorplot('Sex',kind='count',data=df,hue='Survived')

# %% [markdown]
# The count of death is more in male and less in female, while the count of survival is more in female than in male.

# %%
#Factoplot for Embarked
sns.factorplot('Embarked',kind='count',data=df,hue='Survived')

# %% [markdown]
# The count of death is more in people who embarked at port C,and less in other two ports.

# %%
#Factor plot for SibSp
sns.factorplot('SibSp',kind='count',data=df,hue='Survived')

# %% [markdown]
# Death is more in people with 0 SibSP, and less with 8 SibSp.

# %%
#Factor plot for SibSp
sns.factorplot('Parch',kind='count',data=df,hue='Survived')

# %% [markdown]
# People travelling with 0 Parch has death rate more that people travelling with 6 Parch.

# %%
#distplot for age
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# It looks age is almost normally distributed.

# %%
#distplot for fare
sns.distplot(df['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %% [markdown]
# Fare is skewed.

# %% [markdown]
# # Bivariate analysis:

# %%
#Comparision between features using scatter plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Pclass and Sex')
sns.scatterplot(df['Pclass'],df['Sex'],hue=df["Survived"]);

# %% [markdown]
# I can notice that male and female in 1st class are survived, female in class 2 are survived but male are dead, and both male and female are dead in 3rd class.
#
# This gives a outlook that rich people who has selected costliest class are alive that means safty was good with luxurious class, and people who were poor had no safty.

# %%
#Comparision between features using scatter plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Age and SibSp')
sns.scatterplot(df['Age'],df['SibSp'],hue=df["Survived"]);

# %% [markdown]
# It looks like a mixture of deaths and survilance.People with 0-20 age and 5 sibsp are all dead and people with 0 sibsp are mixture of deaths and survived.

# %%
#Comparision between features using scatter plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Parch and Fare')
sns.scatterplot(df['Parch'],df['Fare'],hue=df["Survived"]);

# %% [markdown]
# People above 4 parch are all dead.And people with 0-2 parch are mixtures of survilance and fare is upto 300.

# %%
#Comparision between features using scatter plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Pclass and Embarked')
sns.scatterplot(df['Pclass'],df['Embarked'],hue=df["Survived"]);

# %% [markdown]
# People 1st class are all alive irrespective of port they embarked, 2nd and 3rd class people embarked from S,Q port are survived than C port.

# %% [markdown]
# # Multivariate Analysis:

# %%
#pair ploting for df
sns.pairplot(df,hue="Survived")

# %% [markdown]
# I can notice death rate is more in all paired plots.Which means the survilance rate is very less in this accident.

# %%
def bar_plot(variable):
    var = df[variable]
    varValue = var.value_counts()
    
    plt.figure(figsize = (9,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index, varValue.index.values) # aralık berlirleme
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}:\n{}".format(variable,varValue))

# %%
category1=["Survived","Sex","Pclass","Embarked","SibSp", "Parch"]
for i in category1:
    bar_plot(i)
# Out:
# Survived:
# 0    549
# 1    342
# Name: Survived, dtype: int64
# Sex:
# male      577
# female    314
# Name: Sex, dtype: int64
# Pclass:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
# Embarked:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
# SibSp:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64
# Parch:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
def plot_hist(variable):
    plt.figure(figsize=(9,3))
    plt.hist(df[variable],bins=50)
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title("{} distribution withhist".format(variable))
    plt.show()

# %%
numericVar = ["Fare","Age","PassengerId"]
for i in numericVar:
    plot_hist(i)

# %% [markdown]
# The graph shows most of the passengers were between the age of 20-30 years. Also, the mean age of passengers should be around 25-30 years

# %% [markdown]
# # 3) Basic Data Analysis
# Pclass - Survived
#
# Sex - Survived
#
# SibSp - Survived
#
# Parch - Survived
#
# First class and women's - Survived
#
# Groupby(Pclass and Sex) -- Survived

# %%
# Pclass - Survived
df[["Pclass","Survived"]].groupby(["Pclass"],as_index=False).mean().sort_values(by="Survived",ascending = False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
#Sex - Survived
df[["Sex","Survived"]].groupby(["Sex"],as_index=False).mean().sort_values(by="Survived",ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
#SibSp - Survived
df[["SibSp","Survived"]].groupby(["SibSp"],as_index=False).mean().sort_values(by="Survived",ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
#Parch - Survived
df[["Parch","Survived"]].groupby(["Parch"],as_index=False).mean().sort_values(by="Survived",ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
#First class and women's - Survived
df_filtered = df.loc[(df['Pclass'] == 1) & (df['Sex'] == "female")]
df_filtered[["Pclass","Sex","Survived"]].groupby(["Pclass"],as_index=False).mean().sort_values(by="Survived",ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.968085

# %%
#Groupby(Pclass and Sex) -- Survived
df[["Pclass","Sex","Survived"]].groupby(["Sex","Pclass"]).mean().sort_values(by="Survived",ascending=False)
# Out:
#                Survived
# Sex    Pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.135447

# %%
#calculating the mean age of the passengers
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
#ploting a Kernel Desity Polt based on the Age
fig = sns.FacetGrid(df,hue='Sex',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)

oldest= df['Age'].max()
fig.set(xlim=(0,oldest))

fig.add_legend()

# %%
#ploting a Kernel Desity Polt based on the passengers class
fig = sns.FacetGrid(df,hue='Pclass',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)

oldest= df['Age'].max()
fig.set(xlim=(0,oldest))

fig.add_legend()

# %%
#plotting a linearplot to consider the role played by age in determining chances for survival
sns.lmplot('Age','Survived',data= df)

# %% [markdown]
# We see a general trend that the older the person was, the less likely were his chances of survival.

# %%
#plotting a to monitor the effect of passenger's class and age on chances of survival
sns.lmplot('Age','Survived',hue='Pclass',palette='winter',data= df)

# %%
#using bins for a more clear idea
generations=[10,20,30,40,60,80]
sns.lmplot('Age','Survived',hue='Pclass',palette='winter',data= df,x_bins=generations)

# %%
sns.lmplot('Age','Survived',hue='Sex',palette='winter',data= df,x_bins=generations)

# %% [markdown]
# Older females had a better chances of survival than the rest of the passengers.

# %% [markdown]
# # Label Encoding:

# %%
#Encoding all categorical columns
from sklearn.preprocessing import LabelEncoder
label_encoders = {}
categorical_columns = ['Name','Sex','Ticket','Cabin','Embarked']

for column in categorical_columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# %% [markdown]
# Using Label encoding i have encoded all categorical columns.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0              1         0       3   108    1  22.0      1      0     523
# 1              2         1       1   190    0  38.0      1      0     596
# 2              3         1       3   353    0  26.0      0      0     669
# 3              4         1       1   272    0  35.0      1      0      49
# 4              5         0       3    15    1  35.0      0      0     472
# ..           ...       ...     ...   ...  ...   ...    ...    ...     ...
# 886          887         0       2   548    1  27.0      0      0     101
# 887          888         1       1   303    0  19.0      0      0      14
# 888          889         0       3   413    0   NaN      1      2     675
# 889          890         1       1    81    1  26.0      0      0       8
# 890          891         0       3   220    1  32.0      0      0     466
#
#         Fare  Cabin  Embarked
# 0     7.2500    147         2
# 1    71.2833     81         0
# 2     7.9250    147         2
# 3    53.1000     55         2
# 4     8.0500    147         2
# ..       ...    ...       ...
# 886  13.0000    147         2
# 887  30.0000     30         2
# 888  23.4500    147         2
# 889  30.0000     60         0
# 890   7.7500    147         1
#
# [891 rows x 12 columns]

# %% [markdown]
# This is my data set after encoding.

# %% [markdown]
# # Identifying the outliers:

# %%
#plotting box plot for Age column
sns.boxplot(df["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# Yes there are outliers in Age column.

# %%
#plotting box plot for Age column
sns.boxplot(df["Fare"])
# Out:
# <AxesSubplot:xlabel='Fare'>

# %% [markdown]
# In Fare column also i can find the outliers.

# %% [markdown]
# All other columns with outliers i.e., outliers in categorical columns has no meaning.And also no need to remove them.

# %% [markdown]
# # Treating the null values:

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         0
# dtype: int64

# %% [markdown]
# I have to remove null values in Age column.

# %%
#Treating null values in Age column using median
df["Age"]=df["Age"].fillna(df["Age"].median())

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0              1         0       3   108    1  22.0      1      0     523
# 1              2         1       1   190    0  38.0      1      0     596
# 2              3         1       3   353    0  26.0      0      0     669
# 3              4         1       1   272    0  35.0      1      0      49
# 4              5         0       3    15    1  35.0      0      0     472
# ..           ...       ...     ...   ...  ...   ...    ...    ...     ...
# 886          887         0       2   548    1  27.0      0      0     101
# 887          888         1       1   303    0  19.0      0      0      14
# 888          889         0       3   413    0  28.0      1      2     675
# 889          890         1       1    81    1  26.0      0      0       8
# 890          891         0       3   220    1  32.0      0      0     466
#
#         Fare  Cabin  Embarked
# 0     7.2500    147         2
# 1    71.2833     81         0
# 2     7.9250    147         2
# 3    53.1000     55         2
# 4     8.0500    147         2
# ..       ...    ...       ...
# 886  13.0000    147         2
# 887  30.0000     30         2
# 888  23.4500    147         2
# 889  30.0000     60         0
# 890   7.7500    147         1
#
# [891 rows x 12 columns]

# %% [markdown]
# I Have Used Prediction of missing value

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# Now i can notice there are no null values in my dataset.

# %% [markdown]
# # Removing outliers:

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # i) Zscore method:

# %%
dfContCols = df[["Age", "Fare"]]

# %% [markdown]
# Making a variable as dfContCols and listing all columns with outliers.

# %%
from scipy.stats import zscore
z=np.abs(zscore(dfContCols))
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0              1         0       3   108    1  22.0      1      0     523
# 1              2         1       1   190    0  38.0      1      0     596
# 2              3         1       3   353    0  26.0      0      0     669
# 3              4         1       1   272    0  35.0      1      0      49
# 4              5         0       3    15    1  35.0      0      0     472
# ..           ...       ...     ...   ...  ...   ...    ...    ...     ...
# 886          887         0       2   548    1  27.0      0      0     101
# 887          888         1       1   303    0  19.0      0      0      14
# 888          889         0       3   413    0  28.0      1      2     675
# 889          890         1       1    81    1  26.0      0      0       8
# 890          891         0       3   220    1  32.0      0      0     466
#
#         Fare  Cabin  Embarked
# 0     7.2500    147         2
# 1    71.2833     81         0
# 2     7.9250    147         2
# 3    53.1000     55         2
# 4     8.0500    147         2
# ..       ...    ...       ...
# 886  13.0000    147         2
# 887  30.0000     30         2
# 888  23.4500    147         2
# 889  30.0000     60         0
# 890   7.7500    147         1
#
# [864 rows x 12 columns]

# %%
#Checking shape of new dataset
df_new.shape
# Out:
# (864, 12)

# %%
#Checking shape of old dataset
df.shape
# Out:
# (891, 12)

# %%
#Checking dataloss in Zscore
Dataloss=(((891-864)/891)*100)
Dataloss
# Out:
# 3.0303030303030303

# %% [markdown]
# I have 3.03% dataloss which is less than 10% in zscore method.Let me have a look into IQR method also.

# %% [markdown]
# # ii) IQR method:

# %%
Q1=dfContCols.quantile(0.25)
Q3=dfContCols.quantile(0.75)
IQR=Q3 - Q1

df_1=df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# Using IQR i have removed the outliers.

# %%
#Checking shape of new dataset
df_1.shape
# Out:
# (721, 12)

# %% [markdown]
# In my new data set after removing outliers using IQR i have 721 rows and 12 columns.

# %%
#Checking shape of old dataset
df.shape
# Out:
# (891, 12)

# %%
#Checking dataloss in IQR method
Dataloss=(((891-721)/891)*100)
Dataloss
# Out:
# 19.07968574635241

# %% [markdown]
# I can observe a great dataloss in IQR method, So let me stick on to Zscore method to remove outliers.

# %% [markdown]
# # Checking for Skewness:

# %%
df_new.skew()
# Out:
# PassengerId    0.011620
# Survived       0.502011
# Pclass        -0.708375
# Name          -0.014382
# Sex           -0.632203
# Age            0.321096
# SibSp          3.751753
# Parch          2.840412
# Ticket         0.012485
# Fare           2.257178
# Cabin         -2.387542
# Embarked      -1.308754
# dtype: float64

# %% [markdown]
# I can say there is skewness in
#
# Pclass
#
# Sex
#
# SibSp
#
# Parch
#
# Fare
#
# Cabin
#
# Embarked

# %% [markdown]
# # Removing skewness using yeo-johnson:

# %%
fea=['Pclass','Sex','SibSp','Parch','Fare','Cabin','Embarked']

# %% [markdown]
# Taking a list as fea with all the columns with skewness.

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box_cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box_cox' or 'yeo-johnson'\n"

# %% [markdown]
# Using yeo_johnson method i have removed the skewness.

# %%
df_new[fea] = scaler.fit_transform(df_new[fea].values)

# %%
df_new.skew()
# Out:
# PassengerId    0.011620
# Survived       0.502011
# Pclass        -0.480433
# Name          -0.014382
# Sex           -0.632203
# Age            0.321096
# SibSp          0.805038
# Parch          1.277888
# Ticket         0.012485
# Fare          -0.009095
# Cabin         -1.718018
# Embarked      -0.860511
# dtype: float64

# %% [markdown]
# The skewness is reduced somehow.

# %% [markdown]
# # Correlation matrix with heat map:

# %%
cor=df_new.corr()

# %% [markdown]
# Checking correlations.

# %%
cor
# Out:
#              PassengerId  Survived    Pclass      Name       Sex       Age  \
# PassengerId     1.000000 -0.014399 -0.029821 -0.043518  0.047309  0.026087
# Survived       -0.014399  1.000000 -0.334725 -0.053716 -0.534012 -0.058724
# Pclass         -0.029821 -0.334725  1.000000  0.039166  0.129101 -0.335783
# Name           -0.043518 -0.053716  0.039166  1.000000  0.020680  0.073091
# Sex             0.047309 -0.534012  0.129101  0.020680  1.000000  0.065600
# Age             0.026087 -0.058724 -0.335783  0.073091  0.065600  1.000000
# SibSp          -0.053324  0.103005 -0.060038 -0.091281 -0.198531 -0.157487
# Parch           0.009120  0.141854 -0.001549 -0.045219 -0.249661 -0.270779
# Ticket         -0.064635 -0.175168  0.359153  0.058393  0.061305 -0.097952
# Fare           -0.017867  0.322012 -0.601053 -0.039313 -0.262301  0.110097
# Cabin          -0.023780 -0.293749  0.680540  0.027914  0.118111 -0.268494
# Embarked        0.015772 -0.139426  0.043525 -0.009725  0.099158  0.013958
#
#                 SibSp     Parch    Ticket      Fare     Cabin  Embarked
# PassengerId -0.053324  0.009120 -0.064635 -0.017867 -0.023780  0.015772
# Survived     0.103005  0.141854 -0.175168  0.322012 -0.293749 -0.139426
# Pclass      -0.060038 -0.001549  0.359153 -0.601053  0.680540  0.043525
# Name        -0.091281 -0.045219  0.058393 -0.039313  0.027914 -0.009725
# Sex         -0.198531 -0.249661  0.061305 -0.262301  0.118111  0.099158
# Age         -0.157487 -0.270779 -0.097952  0.110097 -0.268494  0.013958
# SibSp        1.000000  0.436627  0.012016  0.432721 -0.046945 -0.011289
# Parch        0.436627  1.000000  0.003003  0.354063 -0.009421  0.022641
# Ticket       0.012016  0.003003  1.000000 -0.153268  0.278092  0.009390
# Fare         0.432721  0.354063 -0.153268  1.000000 -0.537948 -0.103396
# Cabin       -0.046945 -0.009421  0.278092 -0.537948  1.000000  0.130261
# Embarked    -0.011289  0.022641  0.009390 -0.103396  0.130261  1.000000

# %% [markdown]
# I got all correlations of features with other features.Let me visualize it using heat map.

# %%
plt.figure(figsize=(14,12))
sns.heatmap(df_new.corr(),linewidths=.1,cmap="Blues",annot=True, annot_kws={"size": 7})
plt.yticks(rotation=0);

# %% [markdown]
# I got the observation from heat map that
#
# Passenger ID has less correlation with target variable.
#
# Name has less correlation with target variable.
#
# Age has less correlation with target variable.
#
# SibSp has less correlation with target variable.
#
# Embarked has less correlation with target variable.
#
# There is no multicorrelation issue
#
# If necessary i can remove very less correlated feature with target.

# %% [markdown]
# # Visualizing correlation of target variable using bar plot:

# %%
plt.figure(figsize=(22,7))
df_new.corr()['Survived'].sort_values(ascending=False).drop(['Survived']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# PassengerID is the very least correlated feature with target variable.

# %%
#Droping PassengerId column since it is less correlated with target variable.
df_new = df_new.drop(["PassengerId"],axis=1)

# %%
#Droping Name column since it is less correlated with target variable.
df_new = df_new.drop(["Name"],axis=1)

# %%
df_new
# Out:
#      Survived    Pclass       Sex   Age     SibSp     Parch  Ticket      Fare  \
# 0           0  0.842705  0.733053  22.0  1.374574 -0.548637     523 -0.882769
# 1           1 -1.501903 -1.364158  38.0  1.374574 -0.548637     596  1.529038
# 2           1  0.842705 -1.364158  26.0 -0.680931 -0.548637     669 -0.792444
# 3           1 -1.501903 -1.364158  35.0  1.374574 -0.548637      49  1.216581
# 4           0  0.842705  0.733053  35.0 -0.680931 -0.548637     472 -0.776493
# ..        ...       ...       ...   ...       ...       ...     ...       ...
# 886         0 -0.676050  0.733053  27.0 -0.680931 -0.548637     101 -0.279691
# 887         1 -1.501903 -1.364158  19.0 -0.680931 -0.548637      14  0.607981
# 888         0  0.842705 -1.364158  28.0  1.374574  1.879004     675  0.345275
# 889         1 -1.501903  0.733053  26.0 -0.680931 -0.548637       8  0.607981
# 890         0  0.842705  0.733053  32.0 -0.680931 -0.548637     466 -0.815167
#
#         Cabin  Embarked
# 0    0.482558  0.573241
# 1   -2.211931 -1.801839
# 2    0.482558  0.573241
# 3   -2.358732  0.573241
# 4    0.482558  0.573241
# ..        ...       ...
# 886  0.482558  0.573241
# 887 -2.385902  0.573241
# 888  0.482558  0.573241
# 889 -2.344305 -1.801839
# 890  0.482558 -1.234345
#
# [864 rows x 10 columns]

# %% [markdown]
# # Preprocessing:

# %%
x = df_new.drop("Survived",axis=1)
y = df_new["Survived"]

# %% [markdown]
# Assigned y as target variable and x as remaining features.

# %% [markdown]
# # Scaling data using MinMaxScaler:

# %%
#importing necessary libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
mms=MinMaxScaler()
x = pd.DataFrame(mms.fit_transform(x), columns=x.columns)

# %% [markdown]
# It is the coding for scaling data using MinMaxScaler.

# %%
x
# Out:
#        Pclass  Sex       Age    SibSp     Parch    Ticket      Fare     Cabin  \
# 0    1.000000  1.0  0.329064  0.83479  0.000000  0.769118  0.432617  1.000000
# 1    0.000000  0.0  0.573041  0.83479  0.000000  0.876471  0.848336  0.061227
# 2    1.000000  0.0  0.390058  0.00000  0.000000  0.983824  0.448186  1.000000
# 3    0.000000  0.0  0.527295  0.83479  0.000000  0.072059  0.794478  0.010081
# 4    1.000000  1.0  0.527295  0.00000  0.000000  0.694118  0.450936  1.000000
# ..        ...  ...       ...      ...       ...       ...       ...       ...
# 859  0.352235  1.0  0.405306  0.00000  0.000000  0.148529  0.536569  1.000000
# 860  0.000000  0.0  0.283318  0.00000  0.000000  0.020588  0.689575  0.000615
# 861  1.000000  0.0  0.420555  0.83479  0.990972  0.992647  0.644293  1.000000
# 862  0.000000  1.0  0.390058  0.00000  0.000000  0.011765  0.689575  0.015107
# 863  1.000000  1.0  0.481549  0.00000  0.000000  0.685294  0.444270  1.000000
#
#      Embarked
# 0    0.376728
# 1    0.000000
# 2    0.376728
# 3    0.376728
# 4    0.376728
# ..        ...
# 859  0.376728
# 860  0.376728
# 861  0.376728
# 862  0.000000
# 863  0.090014
#
# [864 rows x 9 columns]

# %% [markdown]
# These are my dependent variables after scalerization.

# %%
y.value_counts()
# Out:
# 0    537
# 1    327
# Name: Survived, dtype: int64

# %% [markdown]
# Since my target data is imbalanced i have to balance it using oversampling.

# %% [markdown]
# # Balancing target column using oversampling:

# %%
# !pip3 install imbalanced-learn --user
# Out:
# ^C

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x, y=SM.fit_resample(x, y)

# %% [markdown]
# Did oversampling using SMOTE.

# %%
y.value_counts()
# Out:
# 0    537
# 1    537
# Name: Survived, dtype: int64

# %% [markdown]
# So now my data looks beautifully balanced.

# %% [markdown]
# # Finding Best random state and accuracy:

# %%
from sklearn.tree import DecisionTreeClassifier
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30, random_state =i)
    mod = DecisionTreeClassifier()
    mod.fit(x_train, y_train)
    pred = mod.predict(x_test)
    acc=accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.8328173374613003  on Random_state  56

# %% [markdown]
# Got best accuracy and random state.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRS)

# %% [markdown]
# Created train and test data.

# %% [markdown]
# # Classification Algorithms:

# %%
#importing necessary libraries.
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.naive_bayes import GaussianNB as NB
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score, accuracy_score

# %% [markdown]
# # i) Logistic Regression:

# %%
LR=LogisticRegression()
LR.fit(x_train,y_train)
pred=LR.predict(x_test)
acc=classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       150
#            1       0.89      0.82      0.85       173
#
#     accuracy                           0.85       323
#    macro avg       0.85      0.85      0.85       323
# weighted avg       0.85      0.85      0.85       323

# %% [markdown]
# Logistic Regression is giving me 80% accuracy.

# %%
cm = confusion_matrix(y_test, pred)

x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Logistic regression')
plt.show()

# %% [markdown]
# We can see the true values and predicted values in Logistic Regression model using confusion matrix.

# %% [markdown]
# # ii) Decision Tree Classifier:

# %%
DTC=DecisionTreeClassifier()
DTC.fit(x_train,y_train)
pred = DTC.predict(x_test)
acc = classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.82       150
#            1       0.84      0.85      0.84       173
#
#     accuracy                           0.83       323
#    macro avg       0.83      0.83      0.83       323
# weighted avg       0.83      0.83      0.83       323

# %% [markdown]
# Decision tree classifier is giving me 85% accuracy.

# %%
cm = confusion_matrix(y_test, pred)

x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Decision Tree Classifier')
plt.show()

# %% [markdown]
# We can see the true values and predicted values in Decision Tree Classifier model using confusion matrix.

# %% [markdown]
# # iii) Random Forest Classifier:

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
pred = RFC.predict(x_test)
acc = classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       150
#            1       0.91      0.88      0.89       173
#
#     accuracy                           0.89       323
#    macro avg       0.89      0.89      0.89       323
# weighted avg       0.89      0.89      0.89       323

# %% [markdown]
# Random Forest Classifier is giving me 86% accuracy.

# %%
cm = confusion_matrix(y_test, pred)

x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Random Forest Classifier')
plt.show()

# %% [markdown]
# We can see the true values and predicted values in Random Forest Classifier model using confusion matrix.

# %% [markdown]
# # iv) Support Vector Classifier:

# %%
SV=SVC()
SV.fit(x_train,y_train)
pred=SV.predict(x_test)
acc=classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85       150
#            1       0.90      0.83      0.86       173
#
#     accuracy                           0.86       323
#    macro avg       0.86      0.86      0.86       323
# weighted avg       0.86      0.86      0.86       323

# %% [markdown]
# Support Vector Classifier is giving me 81% accuracy.

# %%
cm = confusion_matrix(y_test, pred)

x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Support Vector Classifier')
plt.show()

# %% [markdown]
# We can see the true values and predicted values in Support Vector Classifier model using confusion matrix.

# %% [markdown]
# # v) K-Neighbor Classifier:

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred=knn.predict(x_test)
acc=classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83       150
#            1       0.86      0.85      0.85       173
#
#     accuracy                           0.85       323
#    macro avg       0.84      0.84      0.84       323
# weighted avg       0.85      0.85      0.85       323

# %% [markdown]
# K-Neighbor Classifier is giving me 79% accuracy.

# %%
cm = confusion_matrix(y_test, pred)

x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for K-Neighbor Classifier')
plt.show()

# %% [markdown]
# We can see the true values and predicted values in K-Neighbor Classifier model using confusion matrix.

# %% [markdown]
# # Cross Validation:

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(LR,x,y,cv=5).mean())
# Out:
# 0.7867811345359704

# %%
print(cross_val_score(DTC,x,y,cv=5).mean())
# Out:
# 0.7840252119104543

# %%
print(cross_val_score(RFC,x,y,cv=5).mean())
# Out:
# 0.8435731362747229

# %%
print(cross_val_score(SV,x,y,cv=5).mean())
# Out:
# 0.8026081286676809

# %%
print(cross_val_score(knn,x,y,cv=5).mean())
# Out:
# 0.7961225820473811

# %% [markdown]
# Above are the cross validation score of LR, DTC, RFC, SVC and KNN.
#
# By looking into the difference of accuracy of the model and its cross validation score. I found that RFC as best model with less difference.

# %% [markdown]
# # Hyper parameter tuning:

# %%
#importing necessary library
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'criterion':['gini','entropy'],
             'max_depth':np.arange(2,50),
             'max_features':["auto","sqrt","log2"],
             'max_leaf_nodes':[10,20,30]}

# %% [markdown]
# Giving the parameters list for Random Forest Classifier model.

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameter,cv=5)

# %% [markdown]
# Running grid search CV for RFC.

# %%
GCV.fit(x_train,y_train)
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# Building graph of deps:   0%|          | 0/4 [00:00<?, ?it/s]
# Examining @/win-64::__win==0=0:   0%|          | 0/4 [00:00<?, ?it/s]
# Examining imbalanced-learn:  25%|##5       | 1/4 [00:00<?, ?it/s]
# Examining python=3.9:  50%|#####     | 2/4 [00:04<00:04,  2.33s/it]
# Examining python=3.9:  75%|#######5  | 3/4 [00:04<00:01,  1.55s/it]
# Examining @/win-64::__archspec==1=x86_64:  75%|#######5  | 3/4 [00:05<00:01,  1.55s/it]
# Examining @/win-64::__archspec==1=x86_64: 100%|##########| 4/4 [00:05<00:00,  1.24s/it]
#
#
# Determining conflicts:   0%|          | 0/4 [00:00<?, ?it/s]
# Examining conflict for imbalanced-learn python:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - imbalanced-learn -> python[version='2.7.*|3.4.*|3.5.*|3.6.*']
#
# Your python: python=3.9
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10244/3832274812.py in <module>
# ----> 1 GCV.fit(x_train,y_train)
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     873                 return results
#     874
# --> 875             self._run_search(evaluate_candidates)
#     876
#     877             # multimetric is determined here because in the case of a callable
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1373     def _run_search(self, evaluate_candidates):
#    1374         """Search all candidates in param_grid"""
# -> 1375         evaluate_candidates(ParameterGrid(self.param_grid))
#    1376
#    1377
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     820                     )
#     821
# --> 822                 out = parallel(
#     823                     delayed(_fit_and_score)(
#     824                         clone(base_estimator),
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     115     def __call__(self, *args, **kwargs):
#     116         with config_context(**self.config):
# --> 117             return self.function(*args, **kwargs)
#     118
#     119
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684             estimator.fit(X_train, **fit_params)
#     685         else:
# --> 686             estimator.fit(X_train, y_train, **fit_params)
#     687
#     688     except Exception:
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     474             # parallel_backend contexts set at a higher level,
#     475             # since correctness does not rely on using threads.
# --> 476             trees = Parallel(
#     477                 n_jobs=self.n_jobs,
#     478                 verbose=self.verbose,
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     115     def __call__(self, *args, **kwargs):
#     116         with config_context(**self.config):
# --> 117             return self.function(*args, **kwargs)
#     118
#     119
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     187             curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
#     188
# --> 189         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     190     else:
#     191         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input)
#     967         """
#     968
# --> 969         super().fit(
#     970             X,
#     971             y,
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input)
#     426
#     427         if is_classifier(self):
# --> 428             self.tree_ = Tree(self.n_features_in_, self.n_classes_, self.n_outputs_)
#     429         else:
#     430             self.tree_ = Tree(
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree.__cinit__()
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# Training the model.

# %%
GCV.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10244/2182401552.py in <module>
# ----> 1 GCV.best_params_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
  
# Creating the hyperparameter grid 
param_dist = {"max_depth": [3, None],
              "max_features": randint(1, 9),
              "min_samples_leaf": randint(1, 9),
              "criterion": ["gini", "entropy"]}
  
# Instantiating Decision Tree classifier
tree = DecisionTreeClassifier()
  
# Instantiating RandomizedSearchCV object
tree_cv = RandomizedSearchCV(tree, param_dist, cv = 5)
  
tree_cv.fit(X, y)
  
# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))
print("Best score is {}".format(tree_cv.best_score_))

# %% [markdown]
# Got the best parameters for RFC.

# %%
Final_mod=RandomForestClassifier(criterion='entropy',max_depth=29,max_features='auto',max_leaf_nodes=30)
Final_mod.fit(x_train,y_train)
pred=Final_mod.predict(x_test)
acc=accuracy_score(y_test, pred)

print(acc*100)
# Out:
# 92.0

# %% [markdown]
# After tuning RFC i got 87.92% accuracy which is good.

# %% [markdown]
# # ROC-AUC Curve:

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import metrics
from sklearn import model_selection
x, y = datasets.make_classification(random_state=1)
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, random_state=1)
df = LogisticRegression(random_state=134)
df.fit(x_train, y_train)
metrics.plot_roc_curve(df, x_test, y_test)  

plt.show()

# %% [markdown]
# This is the roc curve for Logistic Regression model with AUC=0.99.

# %%
x, y = datasets.make_classification(random_state=1)
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, random_state=1)
df = DecisionTreeClassifier(random_state=134)
df.fit(x_train, y_train)
metrics.plot_roc_curve(df, x_test, y_test)  

plt.show()

# %% [markdown]
# This is the roc curve for DecisionTreeClassifier model with AUC=0.95.

# %%
x, y = datasets.make_classification(random_state=1)
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, random_state=1)
df = RandomForestClassifier(random_state=134)
df.fit(x_train, y_train)
metrics.plot_roc_curve(df, x_test, y_test)  

plt.show()

# %% [markdown]
# This is the roc curve for RandomForestClassifier model with AUC=0.99.

# %%
x, y = datasets.make_classification(random_state=1)
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, random_state=1)
df = SVC(random_state=134)
df.fit(x_train, y_train)
metrics.plot_roc_curve(df, x_test, y_test)  

plt.show()

# %% [markdown]
# This is the roc curve for Support Vector Classifier model with AUC=0.98.

# %%
x, y = datasets.make_classification(random_state=1)
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, random_state=1)
df = KNN()
df.fit(x_train, y_train)
metrics.plot_roc_curve(df, x_test, y_test)  

plt.show()

# %% [markdown]
# This is the roc curve for K-Neighbor Classifier model with AUC=0.77.

# %% [markdown]
# # Saving the model:

# %%
#Saving the model as .pkl file
import joblib
joblib.dump(Final_mod,"Titanic.pkl")
# Out:
# ['Titanic.pkl']

# %% [markdown]
# # Done
